# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
obesity_data = pd.read_csv("obesity_data.csv")

# %%
obesity_data.head()
# Out:
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56       1  173.575262  71.982051  23.891783                      4
# 1   69       1  164.127306  89.959256  33.395209                      2
# 2   46       0  168.072202  72.930629  25.817737                      4
# 3   32       1  168.459633  84.886912  29.912247                      3
# 4   60       1  183.568568  69.038945  20.487903                      3
#
#   ObesityCategory
# 0   Normal weight
# 1           Obese
# 2      Overweight
# 3      Overweight
# 4   Normal weight

# %%
obesity_data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Height                   0
# Weight                   0
# BMI                      0
# PhysicalActivityLevel    0
# ObesityCategory          0
# dtype: int64

# %%
obesity_mapping = {
    'Normal weight': 0,
    'Overweight': 1,
    'Obese': 2
}

obesity_data['ObesityCategory'] = obesity_data['ObesityCategory'].map(obesity_mapping)

# %%
obesity_data['ObesityCategory'].fillna(-1, inplace=True)

# %%
obesity_data.head()
# Out:
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56       1  173.575262  71.982051  23.891783                      4
# 1   69       1  164.127306  89.959256  33.395209                      2
# 2   46       0  168.072202  72.930629  25.817737                      4
# 3   32       1  168.459633  84.886912  29.912247                      3
# 4   60       1  183.568568  69.038945  20.487903                      3
#
#    ObesityCategory
# 0              0.0
# 1              2.0
# 2              1.0
# 3              1.0
# 4              0.0

# %%
obesity_data.describe()
# Out:
#                Age       Gender       Height       Weight          BMI  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     49.857000     0.523000   170.052417    71.205769    24.888317
# std      18.114267     0.499721    10.309971    15.509849     6.193912
# min      18.000000     0.000000   136.115719    26.065730     8.470572
# 25%      35.000000     0.000000   163.514205    61.129629    20.918068
# 50%      50.000000     1.000000   169.801665    71.929072    24.698647
# 75%      66.000000     1.000000   177.353596    81.133746    28.732132
# max      79.000000     1.000000   201.419670   118.907366    50.791898
#
#        PhysicalActivityLevel  ObesityCategory
# count            1000.000000      1000.000000
# mean                2.534000         0.534000
# std                 1.116284         0.957999
# min                 1.000000        -1.000000
# 25%                 2.000000         0.000000
# 50%                 3.000000         0.000000
# 75%                 4.000000         1.000000
# max                 4.000000         2.000000

# %%
obesity_data['ObesityCategory'].value_counts()
# Out:
# ObesityCategory
#  0.0    371
#  1.0    295
#  2.0    191
# -1.0    143
# Name: count, dtype: int64

# %%
X = obesity_data.drop(columns='ObesityCategory', axis=1)
Y = obesity_data['ObesityCategory']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1000, 6) (800, 6) (200, 6)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\K NANDA KUMAR REDDY\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9725

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.975

# %%
#saving the model

# %%
import pickle

# %%
filename = 'obesity_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('obesity_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# Age
# Gender
# Height
# Weight
# BMI
# PhysicalActivityLevel
