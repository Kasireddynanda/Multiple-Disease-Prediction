# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
kidney_data = pd.read_csv("Chronic_Kidney_Dsease_data.csv")

# %%
kidney_data.head()
# Out:
#    Age  Gender        BMI  Smoking  AlcoholConsumption  PhysicalActivity  \
# 0   71       0  31.069414        1            5.128112          1.676220
# 1   34       0  29.692119        1           18.609552          8.377574
# 2   80       1  37.394822        1           11.882429          9.607401
# 3   40       0  31.329680        0           16.020165          0.408871
# 4   43       0  23.726311        0            7.944146          0.780319
#
#    DietQuality  SleepQuality  UrinaryTractInfections  SystolicBP  DiastolicBP  \
# 0     0.240386      4.076434                       0         113           83
# 1     6.503233      7.652813                       0         120           67
# 2     2.104828      4.392786                       0         147          106
# 3     6.964422      6.282274                       0         117           65
# 4     3.097796      4.021639                       0          98           66
#
#    FastingBloodSugar     HbA1c  SerumCreatinine  BUNLevels  ProteinInUrine  \
# 0          72.510788  9.212397         4.962531  25.605949        0.744980
# 1         100.848875  4.604989         3.156799  31.338166        3.052317
# 2         160.989441  5.432599         3.698236  39.738169        1.157839
# 3         188.506620  4.144466         2.868468  21.980958        3.745871
# 4          82.156699  4.262979         3.964877  12.216366        2.570993
#
#    HemoglobinLevels  CholesterolTotal  Target
# 0         16.114679        207.728670       1
# 1         15.349205        189.450727       1
# 2         13.018834        284.137622       1
# 3         15.056339        235.112124       1
# 4         16.690561        258.277566       1

# %%
kidney_data.shape
# Out:
# (1659, 19)

# %%
kidney_data.describe()
# Out:
#                Age       Gender          BMI      Smoking  AlcoholConsumption  \
# count  1659.000000  1659.000000  1659.000000  1659.000000         1659.000000
# mean     54.441230     0.515371    27.620049     0.292948            9.969831
# std      20.549757     0.499914     7.288670     0.455252            5.798787
# min      20.000000     0.000000    15.033888     0.000000            0.021740
# 25%      36.000000     0.000000    21.471449     0.000000            5.051156
# 50%      54.000000     1.000000    27.652077     0.000000            9.951503
# 75%      72.000000     1.000000    34.015849     1.000000           14.967100
# max      90.000000     1.000000    39.993532     1.000000           19.992713
#
#        PhysicalActivity  DietQuality  SleepQuality  UrinaryTractInfections  \
# count       1659.000000  1659.000000   1659.000000             1659.000000
# mean           5.024247     5.028544      6.942324                0.210368
# std            2.866274     2.865777      1.704159                0.407693
# min            0.001186     0.002407      4.001053                0.000000
# 25%            2.555038     2.558443      5.487083                0.000000
# 50%            5.072395     4.989810      6.933255                0.000000
# 75%            7.460563     7.428290      8.346298                0.000000
# max            9.998167     9.998927      9.984197                1.000000
#
#         SystolicBP  DiastolicBP  FastingBloodSugar        HbA1c  \
# count  1659.000000  1659.000000        1659.000000  1659.000000
# mean    134.392405    89.313442         132.529429     6.983682
# std      25.767794    17.354479          36.563035     1.734714
# min      90.000000    60.000000          70.044768     4.000405
# 25%     113.000000    75.000000         100.504503     5.494988
# 50%     134.000000    89.000000         131.478423     6.988001
# 75%     157.000000   104.000000         163.108150     8.523562
# max     179.000000   119.000000         199.960429     9.998393
#
#        SerumCreatinine    BUNLevels  ProteinInUrine  HemoglobinLevels  \
# count      1659.000000  1659.000000     1659.000000       1659.000000
# mean          2.753198    27.578147        2.493736         13.927304
# std           1.317168    12.808062        1.449695          2.338372
# min           0.501799     5.000249        0.000900         10.004223
# 25%           1.583255    16.398275        1.226335         11.839478
# 50%           2.732006    28.077796        2.505260         13.909388
# 75%           3.889830    38.127391        3.748696         16.012084
# max           4.998637    49.990522        4.996343         17.999656
#
#        CholesterolTotal       Target
# count       1659.000000  1659.000000
# mean         224.251158     0.918626
# std           43.666586     0.273492
# min          150.015707     0.000000
# 25%          186.440971     1.000000
# 50%          223.202106     1.000000
# 75%          262.681917     1.000000
# max          299.950846     1.000000

# %%
kidney_data.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# BMI                       0
# Smoking                   0
# AlcoholConsumption        0
# PhysicalActivity          0
# DietQuality               0
# SleepQuality              0
# UrinaryTractInfections    0
# SystolicBP                0
# DiastolicBP               0
# FastingBloodSugar         0
# HbA1c                     0
# SerumCreatinine           0
# BUNLevels                 0
# ProteinInUrine            0
# HemoglobinLevels          0
# CholesterolTotal          0
# Target                    0
# dtype: int64

# %%
kidney_data['Target'].value_counts()
# Out:
# Target
# 1    1524
# 0     135
# Name: count, dtype: int64

# %%
X = kidney_data.drop(columns='Target', axis=1)
Y = kidney_data['Target']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1659, 18) (1327, 18) (332, 18)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\K NANDA KUMAR REDDY\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.921627731725697

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9186746987951807

# %%
#saving the model

# %%
import pickle

# %%
filename = 'kidney_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('kidney_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# Age
# Gender
# BMI
# Smoking
# AlcoholConsumption
# PhysicalActivity
# DietQuality
# SleepQuality
# UrinaryTractInfections
# SystolicBP
# DiastolicBP
# FastingBloodSugar
# HbA1c
# SerumCreatinine
# BUNLevels
# ProteinInUrine
# HemoglobinLevels
# CholesterolTotal
