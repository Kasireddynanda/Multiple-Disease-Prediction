# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
dryeye_data = pd.read_csv("Dry_Eye_Dataset.csv")

# %%
dryeye_data.head()
# Out:
#    Gender  Age  Sleep duration  Sleep quality  Stress level  Heart rate  \
# 0       0   24             9.5              2             1          67
# 1       1   39             9.6              2             3          60
# 2       0   45             5.4              1             5          95
# 3       0   45             5.4              4             5          78
# 4       0   42             5.7              3             2          72
#
#    Daily steps  Physical activity  Height  Weight  ...  Syoking  \
# 0         3000                 31     161      69  ...        0
# 1        12000                 74     164      87  ...        0
# 2        12000                 93     179      94  ...        0
# 3        19000                 32     160      77  ...        0
# 4         4000                173     179      99  ...        0
#
#    yedical issue  Ongoing yedication  Syart device benore bed  \
# 0              1                   1                        0
# ...

# %%
dryeye_data.shape
# Out:
# (20000, 25)

# %%
dryeye_data.describe
# Out:
# <bound method NDFrame.describe of        Gender  Age  Sleep duration  Sleep quality  Stress level  Heart rate  \
# 0           0   24             9.5              2             1          67
# 1           1   39             9.6              2             3          60
# 2           0   45             5.4              1             5          95
# 3           0   45             5.4              4             5          78
# 4           0   42             5.7              3             2          72
# ...       ...  ...             ...            ...           ...         ...
# 19995       1   26             9.4              2             3          91
# 19996       0   39             7.3              3             4          65
# 19997       0   20             8.0              5             3          78
# 19998       1   38             4.5              3             3          60
# 19999       1   37             5.0              5             3          73
#
# ...

# %%
dryeye_data.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# Sleep duration                 0
# Sleep quality                  0
# Stress level                   0
# Heart rate                     0
# Daily steps                    0
# Physical activity              0
# Height                         0
# Weight                         0
# Sleep disorder                 0
# Wake up during night           0
# neel sleepy during day         0
# Canneine consuyption           0
# Alcohol consuyption            0
# Syoking                        0
# yedical issue                  0
# Ongoing yedication             0
# Syart device benore bed        0
# Average screen tiye            0
# Blue-light nilter              0
# Discoynort Eye-strain          0
# Redness in eye                 0
# Itchiness/Irritation in eye    0
# Dry Eye Disease                0
# dtype: int64

# %%
dryeye_data['Dry Eye Disease'].value_counts()
# Out:
# Dry Eye Disease
# 1    13037
# 0     6963
# Name: count, dtype: int64

# %%
X = dryeye_data.drop(columns='Dry Eye Disease', axis=1)
Y = dryeye_data['Dry Eye Disease']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (20000, 24) (16000, 24) (4000, 24)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\K NANDA KUMAR REDDY\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.651875

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.65175

# %%
#saving the model

# %%
import pickle

# %%
filename = 'DryEye_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('DryEye_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# Gender
# Age
# Sleep duration
# Sleep quality
# Stress level
# Heart rate
# Daily steps
# Physical activity
# Height
# Weight
# Sleep disorder
# Wake up during night
# neel sleepy during day
# Canneine consuyption
# Alcohol consuyption
# Syoking
# yedical issue
# Ongoing yedication
# Syart device benore bed
# Average screen tiye
# Blue-light nilter
# Discoynort Eye-strain
# Redness in eye
# Itchiness/Irritation in eye
