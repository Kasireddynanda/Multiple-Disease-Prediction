# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
dementia_data = pd.read_csv("dementia_dataset.csv")

# %%
dementia_data.head()
# Out:
#    Gender  Age  EDUC  Socioeconomic Status  Mini-Mental State Examination  \
# 0       1   87    14                   2.0                           27.0
# 1       1   88    14                   2.0                           30.0
# 2       1   75    12                   NaN                           23.0
# 3       1   76    12                   NaN                           28.0
# 4       1   80    12                   NaN                           22.0
#
#    Clinical Dementia Rating  Estimated Total Intracranial Volume  \
# 0                       0.0                                 1987
# 1                       0.0                                 2004
# 2                       0.5                                 1678
# 3                       0.5                                 1738
# 4                       0.5                                 1698
#
#    Normalized Whole Brain Volume  Atlas Scaling Factor       Target
# 0                          0.696                 0.883  Nondemented
# 1                          0.681                 0.876  Nondemented
# 2                          0.736                 1.046     Demented
# 3                          0.713                 1.010     Demented
# 4                          0.701                 1.034     Demented

# %%
dementia_data.describe()
# Out:
#            Gender         Age        EDUC  Socioeconomic Status  \
# count  373.000000  373.000000  373.000000            354.000000
# mean     0.428954   77.013405   14.597855              2.460452
# std      0.495592    7.640957    2.876339              1.134005
# min      0.000000   60.000000    6.000000              1.000000
# 25%      0.000000   71.000000   12.000000              2.000000
# 50%      0.000000   77.000000   15.000000              2.000000
# 75%      1.000000   82.000000   16.000000              3.000000
# max      1.000000   98.000000   23.000000              5.000000
#
#        Mini-Mental State Examination  Clinical Dementia Rating  \
# count                     371.000000                373.000000
# mean                       27.342318                  0.290885
# std                         3.683244                  0.374557
# min                         4.000000                  0.000000
# 25%                        27.000000                  0.000000
# 50%                        29.000000                  0.000000
# 75%                        30.000000                  0.500000
# max                        30.000000                  2.000000
#
#        Estimated Total Intracranial Volume  Normalized Whole Brain Volume  \
# count                           373.000000                     373.000000
# mean                           1488.128686                       0.729568
# std                             176.139286                       0.037135
# min                            1106.000000                       0.644000
# 25%                            1357.000000                       0.700000
# 50%                            1470.000000                       0.729000
# 75%                            1597.000000                       0.756000
# max                            2004.000000                       0.837000
#
#        Atlas Scaling Factor
# count            373.000000
# mean               1.195461
# std                0.138092
# min                0.876000
# 25%                1.099000
# 50%                1.194000
# 75%                1.293000
# max                1.587000

# %%
dementia_data.isnull().sum()
# Out:
# Gender                                  0
# Age                                     0
# EDUC                                    0
# Socioeconomic Status                   19
# Mini-Mental State Examination           2
# Clinical Dementia Rating                0
# Estimated Total Intracranial Volume     0
# Normalized Whole Brain Volume           0
# Atlas Scaling Factor                    0
# Target                                  0
# dtype: int64

# %%
dementia_data.dropna(inplace=True)

# %%
dementia_data.isnull().sum()
# Out:
# Gender                                 0
# Age                                    0
# EDUC                                   0
# Socioeconomic Status                   0
# Mini-Mental State Examination          0
# Clinical Dementia Rating               0
# Estimated Total Intracranial Volume    0
# Normalized Whole Brain Volume          0
# Atlas Scaling Factor                   0
# Target                                 0
# dtype: int64

# %%
dementia_mapping = {
    'Nondemented': 0,
    'Demented': 1,
}

# %%
dementia_data['Target'] = dementia_data['Target'].map(dementia_mapping)

# %%
dementia_data['Target'].fillna(-1, inplace=True)
# Out:
# C:\Users\K NANDA KUMAR REDDY\AppData\Local\Temp\ipykernel_9864\758162482.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dementia_data['Target'].fillna(-1, inplace=True)

# %%
dementia_data.head()
# Out:
#    Gender  Age  EDUC  Socioeconomic Status  Mini-Mental State Examination  \
# 0       1   87    14                   2.0                           27.0
# 1       1   88    14                   2.0                           30.0
# 5       0   88    18                   3.0                           28.0
# 6       0   90    18                   3.0                           27.0
# 7       1   80    12                   4.0                           28.0
#
#    Clinical Dementia Rating  Estimated Total Intracranial Volume  \
# 0                       0.0                                 1987
# 1                       0.0                                 2004
# 5                       0.0                                 1215
# 6                       0.0                                 1200
# 7                       0.0                                 1689
#
#    Normalized Whole Brain Volume  Atlas Scaling Factor  Target
# 0                          0.696                 0.883     0.0
# 1                          0.681                 0.876     0.0
# 5                          0.710                 1.444     0.0
# 6                          0.718                 1.462     0.0
# 7                          0.712                 1.039     0.0

# %%
dementia_data['Target'].value_counts()
# Out:
# Target
#  0.0    190
#  1.0    127
# -1.0     37
# Name: count, dtype: int64

# %%
X = dementia_data.drop(columns='Target', axis=1)
Y = dementia_data['Target']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (354, 9) (283, 9) (71, 9)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\K NANDA KUMAR REDDY\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.7420494699646644

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.7323943661971831

# %%
#saving the model

# %%
import pickle

# %%
filename = 'dementia_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('dementia_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# Gender
# Age
# EDUC
# Socioeconomic Status
# Mini-Mental State Examination
# Clinical Dementia Rating
# Estimated Total Intracranial Volume
# Normalized Whole Brain Volume
# Atlas Scaling Factor
